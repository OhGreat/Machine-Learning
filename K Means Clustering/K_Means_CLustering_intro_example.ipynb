# %% [markdown]
# the overall goal is to divide data into distinct groups such
# that observations between each group are similar
#
#  we use make_blobs to create artificial data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
sns.set_style(style='whitegrid')

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=200,n_features=2, centers=4, cluster_std=1.8, random_state=101)

# %%
data[0].shape
# Out:
# (200, 2)

# %%
sns.scatterplot(data[0][:,0],data[0][:,1],hue=data[1])

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=4)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[-9.46941837, -6.56081545],
#        [ 3.71749226,  7.01388735],
#        [-0.0123077 ,  2.13407664],
#        [-4.13591321,  7.95389851]])

# %%
kmeans.labels_
# Out:
# array([3, 1, 2, 1, 1, 0, 1, 2, 1, 2, 3, 2, 1, 1, 3, 2, 1, 2, 0, 3, 0, 2,
#        2, 0, 3, 0, 0, 2, 1, 1, 3, 0, 1, 2, 2, 3, 0, 0, 0, 2, 0, 3, 3, 3,
#        2, 1, 3, 2, 0, 2, 2, 3, 1, 2, 0, 3, 2, 2, 3, 1, 0, 1, 0, 3, 1, 2,
#        0, 1, 1, 0, 1, 2, 0, 2, 0, 1, 1, 2, 3, 2, 2, 0, 1, 0, 2, 2, 2, 3,
#        2, 0, 0, 0, 0, 2, 2, 0, 1, 3, 0, 1, 2, 0, 2, 2, 1, 2, 0, 1, 0, 0,
#        1, 3, 3, 1, 0, 1, 3, 3, 1, 3, 2, 3, 2, 3, 2, 1, 3, 2, 0, 3, 3, 3,
#        2, 0, 0, 3, 1, 3, 1, 2, 0, 1, 0, 3, 3, 1, 2, 0, 3, 3, 3, 3, 2, 1,
#        2, 3, 1, 1, 1, 2, 1, 2, 2, 3, 0, 3, 2, 1, 3, 2, 1, 2, 3, 1, 2, 3,
#        1, 1, 0, 1, 3, 0, 0, 3, 0, 0, 0, 0, 0, 2, 0, 1, 1, 3, 0, 2, 1, 1,
#        0, 2], dtype=int32)

# %%
fig , (ax1,ax2) = plt.subplots(1,2, sharey=True, figsize=(12,6))
ax1.set_title('K Means')
ax1.scatter(data[0][:,0], data[0][:,1],c=kmeans.labels_, cmap='rainbow')

ax2.set_title('Original')
ax2.scatter(data[0][:,0], data[0][:,1], c=data[1], cmap='rainbow')

# %%
#by changing the n_clusters on KMeans model intresting things happen :P

# %%
kmeans2 = KMeans(n_clusters=2)
kmeans2.fit(data[0])
fig , (ax1,ax2) = plt.subplots(1,2, sharey=True, figsize=(12,6))
ax1.set_title('K Means')
ax1.scatter(data[0][:,0], data[0][:,1],c=kmeans2.labels_, cmap='rainbow')

ax2.set_title('Original')
ax2.scatter(data[0][:,0], data[0][:,1], c=data[1], cmap='rainbow')
